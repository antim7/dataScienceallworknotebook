# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
exp_vals=[1400,600,300,410,250]
exp_lebals=['Home_rent','Food','Phone/internetbill','Car','Otherutilities']

# %%
plt.pie(exp_vals,labels=exp_lebals)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d4fc09eb50>,
# ...
#  [Text(0.09328656407206024, 1.0960372333838069, 'Home_rent'),
#   Text(-0.9822184890776084, -0.4952240298229684, 'Food'),
#   Text(-0.16284704617934698, -1.0878790555712807, 'Phone/internetbill'),
#   Text(0.6256100334857941, -0.9047718419590123, 'Car'),
#   Text(1.0615045230766318, -0.28845822485734873, 'Otherutilities')])

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_lebals,radius=1.5,autopct="%0.1f%%",shadow=True)
plt.show()
