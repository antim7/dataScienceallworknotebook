# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_customers = pd.read_csv('Test.csv', index_col=0)
df_customers
# Out:
#         Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# ID
# 458989  Female          Yes   36       Yes       Engineer              0.0
# 458994    Male          Yes   37       Yes     Healthcare              8.0
# 458996  Female          Yes   69        No            NaN              0.0
# 459000    Male          Yes   59        No      Executive             11.0
# 459001  Female           No   19        No      Marketing              NaN
# ...        ...          ...  ...       ...            ...              ...
# 467954    Male           No   29        No     Healthcare              9.0
# 467958  Female           No   35       Yes         Doctor              1.0
# 467960  Female           No   53       Yes  Entertainment              NaN
# 467961    Male          Yes   47       Yes      Executive              1.0
# 467968  Female           No   43       Yes     Healthcare              9.0
#
#        Spending_Score  Family_Size  Var_1
# ID
# 458989            Low          1.0  Cat_6
# 458994        Average          4.0  Cat_6
# 458996            Low          1.0  Cat_6
# 459000           High          2.0  Cat_6
# 459001            Low          4.0  Cat_6
# ...               ...          ...    ...
# 467954            Low          4.0  Cat_6
# 467958            Low          1.0  Cat_6
# 467960            Low          2.0  Cat_6
# 467961           High          5.0  Cat_4
# 467968            Low          3.0  Cat_7
#
# [2627 rows x 9 columns]

# %%
df_customers.describe()
# Out:
#                Age  Work_Experience  Family_Size
# count  2627.000000      2358.000000  2514.000000
# mean     43.649791         2.552587     2.825378
# std      16.967015         3.341094     1.551906
# min      18.000000         0.000000     1.000000
# 25%      30.000000         0.000000     2.000000
# 50%      41.000000         1.000000     2.000000
# 75%      53.000000         4.000000     4.000000
# max      89.000000        14.000000     9.000000

# %%
df_customers.corr()
# Out:
#                       Age  Work_Experience  Family_Size
# Age              1.000000        -0.186238    -0.285237
# Work_Experience -0.186238         1.000000    -0.071253
# Family_Size     -0.285237        -0.071253     1.000000

# %%
plt.figure(figsize=(12,9))
s = sns.heatmap(df_customers.corr(),
                annot=True,
                cmap='RdBu',
                vmin=-1,
                vmax=1)
s.set_xticklabels(s.get_xticklabels(), rotation=90)
plt.title('Correlation Matrix')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
customers_std = scaler.fit_transform(df_customers)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13216\1100583988.py in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
# ----> 3 customers_std = scaler.fit_transform(df_customers)
#
# F:\Antim_Doc_softwar\anaconda\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# F:\Antim_Doc_softwar\anaconda\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# F:\Antim_Doc_softwar\anaconda\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     839         """
#     840         first_call = not hasattr(self, "n_samples_seen_")
# --> 841         X = self._validate_data(
#     842             X,
#     843             accept_sparse=("csr", "csc"),
#
# F:\Antim_Doc_softwar\anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# F:\Antim_Doc_softwar\anaconda\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# F:\Antim_Doc_softwar\anaconda\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    2062
#    2063     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064         return np.asarray(self._values, dtype=dtype)
#    2065
#    2066     def __array_wrap__(
#
# ValueError: could not convert string to float: 'Female'

# %%
h_cluster = linkage(customers_std, method='ward')

plt.figure(figsize=(12, 9))
plt.xlabel('Observations')
plt.ylabel('Distance')
dendrogram(h_cluster,
           show_leaf_counts=False,
           no_labels=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13216\572021261.py in <module>
# ----> 1 h_cluster = linkage(customers_std, method='ward')
#       2
#       3 plt.figure(figsize=(12, 9))
#       4 plt.xlabel('Observations')
#       5 plt.ylabel('Distance')
#
# NameError: name 'linkage' is not defined
