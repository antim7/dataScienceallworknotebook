# %%
import pandas as pd
df = pd.read_csv("weather_data2.csv")
df
# Out:
#          Day      city  temperature  windspeed   event
# 0   1/1/2023  new york           32          6    Rain
# 1   1/2/2023  new york           35          7   Sunny
# 2   1/3/2023  new york           36         12    Snow
# 3   1/4/2023  new york           33          7   Sunny
# 4   1/1/2023    mumbai           90          5     Fog
# 5   1/2/2023    mumbai           85         12     Fog
# 6   1/3/2023    mumbai           87         15    Rain
# 7   1/4/2023    mumbai           92          5  Cloudy
# 8   1/1/2023     paris           45         20   Sunny
# 9   1/2/2023     paris           50         13  Cloudy
# 10  1/3/2023     paris           54          8  Cloudy
# 11  1/4/2023     paris           42         10  Cloudy

# %%
g=df.groupby('city')
g

# %%
for city,city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#         Day    city  temperature  windspeed   event
# 4  1/1/2023  mumbai           90          5     Fog
# 5  1/2/2023  mumbai           85         12     Fog
# 6  1/3/2023  mumbai           87         15    Rain
# 7  1/4/2023  mumbai           92          5  Cloudy
# new york
#         Day      city  temperature  windspeed  event
# 0  1/1/2023  new york           32          6   Rain
# 1  1/2/2023  new york           35          7  Sunny
# 2  1/3/2023  new york           36         12   Snow
# 3  1/4/2023  new york           33          7  Sunny
# paris
#          Day   city  temperature  windspeed   event
# 8   1/1/2023  paris           45         20   Sunny
# 9   1/2/2023  paris           50         13  Cloudy
# 10  1/3/2023  paris           54          8  Cloudy
# 11  1/4/2023  paris           42         10  Cloudy

# %%
g.get_group('mumbai')
# Out:
#         Day    city  temperature  windspeed   event
# 4  1/1/2023  mumbai           90          5     Fog
# 5  1/2/2023  mumbai           85         12     Fog
# 6  1/3/2023  mumbai           87         15    Rain
# 7  1/4/2023  mumbai           92          5  Cloudy

# %%
g.max()
# Out:
#                Day  temperature  windspeed  event
# city
# mumbai    1/4/2023           92         15   Rain
# new york  1/4/2023           36         12  Sunny
# paris     1/4/2023           54         20  Sunny

# %%
g.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        34.00       8.00
# paris           47.75      12.75

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  34.00  1.825742  32.0  32.75  34.0  35.25  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.11;0.775x0.77)
# new york    AxesSubplot(0.125,0.11;0.775x0.77)
# paris       AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object
