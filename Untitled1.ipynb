# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,53,48,47,49]

# %%
plt.plot(x,y)

# %%
v0=20;
g=9.8;
t=0;
y=0;
time=[];
location=[];
while y>=0area=fact(3)
    disp(['At time t = ',num2str(t),' Location = ',num2str(y)])
    y = v0*t-g*t^2/2;
    t=t+0.1;
    time=[time,t];
    location=[location,y];
endwhile
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp\ipykernel_6692\1922909979.py", line 7
#     while y>=0;
#               ^
# SyntaxError: invalid syntax

# %%
from * import script.m
script(6)
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp\ipykernel_6692\3985286812.py", line 1
#     from * import script.m
#          ^
# SyntaxError: invalid syntax
